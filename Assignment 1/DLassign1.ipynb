# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
# Scale down values of pixels from 0-255 to 0-1(to reduce the computational cost we scale down as scaling down 0-255 is hard so we scale down to 0-1)
train_images = train_images /255.0
test_images = test_images / 255.0

# %%
print(train_images.shape)
print(test_images.shape)
print(train_labels)

# Display first image
plt.imshow(train_images[1], cmap='gray')
plt.show()
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# [5 0 4 ... 5 6 8]

# %%
# Defining neural network model
my_model = tf.keras.models.Sequential()
my_model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
my_model.add(tf.keras.layers.Dense(128, activation='relu'))     #Rectified Linear Unit        #Dense layers are used to learn complex patterns in data.
my_model.add(tf.keras.layers.Dense(10, activation='softmax'))   #softmax is often used as the activation function in the output layer for classification tasks

# Compiling the model
my_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']) #Adaptive Moment Estimation #sparse_categorical_crossentropy for multi-class classification

# Training the model(no.of epochs more the more computational cost)
my_model.fit(train_images, train_labels, epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9258 - loss: 0.2615
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9654 - loss: 0.1171
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9758 - loss: 0.0798

# %%
# Checking model accuracy on test data
val_loss, val_acc = my_model.evaluate(test_images, test_labels)
print('Test accuracy: ', val_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9710 - loss: 0.0927
# Test accuracy:  0.9710000157356262

# %%
my_model.save("my_mnist_model.keras")

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
train_images = train_images /255.0
test_images = test_images / 255.0

# %%
print(train_images.shape)
print(test_images.shape)
print(train_labels)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# [9 0 0 ... 3 0 5]

# %%
plt.imshow(train_images[1], cmap='gray')
plt.show()

# %%
plt.imshow(train_images[2], cmap='gray')
plt.show()

# %%
plt.imshow(train_images[0], cmap='gray')
plt.show()

# %%
my_model = tf.keras.models.Sequential()
my_model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
my_model.add(tf.keras.layers.Dense(128, activation='relu'))     #Rectified Linear Unit        #Dense layers are used to learn complex patterns in data.
my_model.add(tf.keras.layers.Dense(10, activation='softmax'))   #softmax is often used as the activation function in the output layer for classification tasks

# Compiling the model
my_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']) #Adaptive Moment Estimation #sparse_categorical_crossentropy for multi-class classification

# Training the model(no.of epochs more the more computational cost)
my_model.fit(train_images, train_labels, epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8256 - loss: 0.4956
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8655 - loss: 0.3747
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8778 - loss: 0.3345

# %%
# Checking model accuracy on test data
val_loss, val_acc = my_model.evaluate(test_images, test_labels)
print('Test accuracy: ', val_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8735 - loss: 0.3610
# Test accuracy:  0.8734999895095825

# %%
my_model.save("fashion_mnist.keras")

# %%
train_images = train_images /255.0
test_images = test_images / 255.0

# %%
print(train_images.shape)
print(test_images.shape)
print(train_labels)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# [9 0 0 ... 3 0 5]

# %%
plt.imshow(train_images[0], cmap='gray')
plt.show()

# %%
my_model = tf.keras.models.Sequential()
my_model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
my_model.add(tf.keras.layers.Dense(128, activation='relu'))     #Rectified Linear Unit        #Dense layers are used to learn complex patterns in data.
my_model.add(tf.keras.layers.Dense(10, activation='softmax'))   #softmax is often used as the activation function in the output layer for classification tasks

# Compiling the model
my_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']) #Adaptive Moment Estimation #sparse_categorical_crossentropy for multi-class classification

# Training the model(no.of epochs more the more computational cost)
my_model.fit(train_images, train_labels, epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.0986 - loss: 2.3028
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.0976 - loss: 2.3028
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.1000 - loss: 2.3028

# %%
# Checking model accuracy on test data
val_loss, val_acc = my_model.evaluate(test_images, test_labels)
print('Test accuracy: ', val_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1000 - loss: 2.3026
# Test accuracy:  0.10000000149011612

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
#   2621440/170498071 ━━━━━━━━━━━━━━━━━━━━ 51:10 18us/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_731/2242790803.py in <cell line: 0>()
# ----> 1 (train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
#
# /usr/local/lib/python3.12/dist-packages/keras/src/datasets/cifar10.py in load_data()
#      68     dirname = "cifar-10-batches-py-target"
#      69     origin = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# ---> 70     path = get_file(
#      71         fname=dirname,
#      72         origin=origin,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/file_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     352         try:
#     353             try:
# --> 354                 urlretrieve(origin, download_target, DLProgbar())
#     355             except urllib.error.HTTPError as e:
#     356                 raise Exception(error_msg.format(origin, e.code, e.msg))
#
# /usr/lib/python3.12/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     266                 reporthook(blocknum, bs, size)
#     267
# --> 268             while block := fp.read(bs):
#     269                 read += len(block)
#     270                 tfp.write(block)
#
# /usr/lib/python3.12/http/client.py in read(self, amt)
#     482                 # clip the read to the "end of response"
#     483                 amt = self.length
# --> 484             s = self.fp.read(amt)
#     485             if not s and amt:
#     486                 # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.12/socket.py in readinto(self, b)
#     718         while True:
#     719             try:
# --> 720                 return self._sock.recv_into(b)
#     721             except timeout:
#     722                 self._timeout_occurred = True
#
# /usr/lib/python3.12/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1249                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250                   self.__class__)
# -> 1251             return self.read(nbytes, buffer)
#    1252         else:
#    1253             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.12/ssl.py in read(self, len, buffer)
#    1101         try:
#    1102             if buffer is not None:
# -> 1103                 return self._sslobj.read(len, buffer)
#    1104             else:
#    1105                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
train_images = train_images /255.0
test_images = test_images / 255.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_731/1725108542.py in <cell line: 0>()
# ----> 1 train_images = train_images /255.0
#       2 test_images = test_images / 255.0
#
# NameError: name 'train_images' is not defined

# %%
print(train_images.shape)
print(test_images.shape)
print(train_labels)

# Display first image
plt.imshow(train_images[0], cmap='gray')
plt.show()
plt.imshow(train_images[2], cmap='gray')
plt.show()
plt.imshow(train_images[5], cmap='gray')
plt.show()
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]

# %%
my_model = tf.keras.models.Sequential()
my_model.add(tf.keras.layers.Flatten(input_shape=(32, 32, 3)))
my_model.add(tf.keras.layers.Dense(128, activation='relu'))     #Rectified Linear Unit        #Dense layers are used to learn complex patterns in data.
my_model.add(tf.keras.layers.Dense(10, activation='softmax'))   #softmax is often used as the activation function in the output layer for classification tasks

# Compiling the model
my_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']) #Adaptive Moment Estimation #sparse_categorical_crossentropy for multi-class classification

# Training the model(no.of epochs more the more computational cost)
my_model.fit(train_images, train_labels, epochs=3)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_731/3559219415.py in <cell line: 0>()
#       8
#       9 # Training the model(no.of epochs more the more computational cost)
# ---> 10 my_model.fit(train_images, train_labels, epochs=3)
#
# NameError: name 'train_images' is not defined

# %%
val_loss, val_acc = my_model.evaluate(test_images, test_labels)
print('Test accuracy: ', val_acc)
